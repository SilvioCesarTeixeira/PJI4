# %% [markdown]
# <a href="https://colab.research.google.com/github/SilvioCesarTeixeira/PJI4/blob/master/PIJ4_ETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instalar e Importar Bibliotecas

# %%
# !pip install openpyxl
# !pip install pyexcel
# !pip install sweetviz
# !pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.9/dist-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.9/dist-packages (from openpyxl) (1.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyexcel in /usr/local/lib/python3.9/dist-packages (0.7.0)
# Requirement already satisfied: texttable>=0.8.2 in /usr/local/lib/python3.9/dist-packages (from pyexcel) (1.6.7)
# Requirement already satisfied: pyexcel-io>=0.6.2 in /usr/local/lib/python3.9/dist-packages (from pyexcel) (0.6.6)
# Requirement already satisfied: lml>=0.0.4 in /usr/local/lib/python3.9/dist-packages (from pyexcel) (0.1.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.9/dist-packages (from pyexcel) (4.0.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sweetviz in /usr/local/lib/python3.9/dist-packages (2.1.4)
# Requirement already satisfied: importlib-resources>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from sweetviz) (5.12.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /usr/local/lib/python3.9/dist-packages (from sweetviz) (1.3.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from sweetviz) (1.10.1)
# Requirement already satisfied: tqdm>=4.43.0 in /usr/local/lib/python3.9/dist-packages (from sweetviz) (4.65.0)
# Requirement already satisfied: matplotlib>=3.1.3 in /usr/local/lib/python3.9/dist-packages (from sweetviz) (3.5.3)
# Requirement already satisfied: jinja2>=2.11.1 in /usr/local/lib/python3.9/dist-packages (from sweetviz) (3.1.2)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from sweetviz) (1.22.4)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=1.2.0->sweetviz) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2>=2.11.1->sweetviz) (2.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.3->sweetviz) (4.39.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.3->sweetviz) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.3->sweetviz) (8.4.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in /usr/local/lib/python3.9/dist-packages (from seaborn) (3.5.3)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from seaborn) (1.10.1)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.9/dist-packages (from seaborn) (1.22.4)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.9/dist-packages (from seaborn) (1.3.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (4.39.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.23->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.15.0)

# %%
import pandas as pd
#from google.colab import files
import io
import openpyxl
import sweetviz as sv
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Se for carregar arquivo do computador, deve retirar o caracter # da frente da linha de código logo abaixo e escolher os arquivos

# %%
#uploaded = files.upload()

# %% [markdown]
# Definir caminho para os arquivos de dados

# %%
url_SG = r'https://github.com/SilvioCesarTeixeira/PJI4/raw/master/A170043189_40_88_59.xlsx'
url_QA = r'https://github.com/SilvioCesarTeixeira/PJI4/raw/master/QA_ITP_SMP.xlsx'

# %% [markdown]
# Criar Dataframes

# %%
df1 = pd.read_excel(url_QA, engine='openpyxl')
df2 = pd.read_excel(url_SG, engine='openpyxl')
df2
# Out:
#      Fonte TABNET – Secretaria Municipal da Saúde da Prefeitura de São Paulo -sp  \
# 0                 COVID19 e-SUS-VE S�ndrome Gripal (SG)
# 1     N� de Casos por Ano M�s Dia Notifica��o e Subp...
# 2                    Subprefeitura(Res): ITAIM PAULISTA
# 3                             Per�odo:Jan/2020-Mar/2023
# 4                               Ano M�s Dia Notifica��o
# ...                                                 ...
# 1100  1. Se for utilizar per�odos menores (como de 3...
# 1101                 2. Se selecionar todos os per�odos
# 1102   3. Os bancos est�o separados por m�s de inici...
# 1103  4. Informamos que devido a atualiza��o no sist...
# 1104  5. Seguindo orienta��o da Nota T�cnica 14/2022...
#
#                                              Unnamed: 1  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                            SAO MIGUEL
# 3                                                   NaN
# 4                                        ITAIM PAULISTA
# ...                                                 ...
# 1100   por exemplo) o(s) per�odo(s) selecionado(s) n...
# 1101                 o resultado trar� o total de casos
# 1102                                                NaN
# 1103                                                NaN
# 1104   que exclui os crit�rios cl�nico e cl�nico-ima...
#
#                                              Unnamed: 2 Unnamed: 3
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                            SAO MIGUEL      Total
# ...                                                 ...        ...
# 1100                                                NaN        NaN
# 1101   mas o tempo de processamento aumentar� propor...        NaN
# 1102                                                NaN        NaN
# 1103                                                NaN        NaN
# 1104   mantendo apenas os crit�rios cl�nico-epidemio...     a equi
#
# [1105 rows x 4 columns]

# %% [markdown]
# Definir a linha zero do dataframe 1 como título das colunas

# %%
df1
df1.columns = df1.iloc[0]
df1 = df1.reindex(df1.index.drop(0))
df1
# Out:
# 0          date  pm25  pm10  o3  no2  so2  co
# 1      2023/3/2    44    19  41    8
# 2      2023/3/3    54    24  45    9
# 3      2023/3/4    52    22  29   10
# 4      2023/3/5    49    20  10   10
# 5      2023/2/5    56        29    6
# ...         ...   ...   ...  ..  ...  ...  ..
# 3052   2014/4/1              27
# 3053  2018/9/19                   12    1   6
# 3054  2019/6/10                         1   5
# 3055  2018/9/17                             3
# 3056  2018/9/18                             5
#
# [3056 rows x 7 columns]

# %% [markdown]
# Definindo a primeira coluna como data com padrão Português do Brasil

# %%
df1['Data'] = pd.to_datetime(df1['date'], format='%Y/%m/%d').dt.strftime('%d/%m/%Y')
col_Data_correta = df1.iloc[:, -1]
df1 = df1.iloc[:, 1:-1]
df1.insert(loc=0, column='Data', value=col_Data_correta)
df1
# Out:
# 0           Data  pm25  pm10  o3  no2  so2  co
# 1     02/03/2023    44    19  41    8
# 2     03/03/2023    54    24  45    9
# 3     04/03/2023    52    22  29   10
# 4     05/03/2023    49    20  10   10
# 5     05/02/2023    56        29    6
# ...          ...   ...   ...  ..  ...  ...  ..
# 3052  01/04/2014              27
# 3053  19/09/2018                   12    1   6
# 3054  10/06/2019                         1   5
# 3055  17/09/2018                             3
# 3056  18/09/2018                             5
#
# [3056 rows x 7 columns]

# %%
df2.columns = df2.iloc[4]
linhas_remover = list(range(0,5)) + list(range(1097,1105))
df2 = df2.reindex(df2.index.drop(linhas_remover))
df2 = df2.rename(columns={'Ano M�s Dia Notifica��o': 'Data'})
df2
# Out:
# 4           Data ITAIM PAULISTA SAO MIGUEL Total
# 5     03/01/2020              4          5     9
# 6     04/01/2020              9         17    26
# 7     05/01/2020              4          3     7
# 8     20/01/2020              -          1     1
# 9     23/01/2020              1          -     1
# ...          ...            ...        ...   ...
# 1092  26/02/2023             28         45    73
# 1093  27/02/2023            132        184   316
# 1094  28/02/2023            178        158   336
# 1095  01/03/2023             96        172   268
# 1096  02/03/2023              5         21    26
#
# [1092 rows x 4 columns]

# %% [markdown]
# Juntar os dois dataframes, mas mantendo apenas as datas que coincidem

# %%
df_base = pd.merge(df1, df2, how='inner', on='Data')

# %% [markdown]
# Definir uma data de corte

# %%
data_limite = '01/01/2020'
#df_base['Data'] = pd.to_datetime(df_base['Data'], format='%d/%m/%Y')
df_base = df_base.loc[df_base['Data'] > data_limite]

# %%
df_base.describe()
# Out:
#              pm25        pm10          o3         no2        IT_SG  \
# count  948.000000  998.000000  995.000000  975.000000  1021.000000
# mean    51.345992   24.273547   26.905528    8.534359   191.833497
# std     24.464972   13.665451   10.008805    4.799747   158.961679
# min      9.000000    3.000000    4.000000    1.000000     1.000000
# 25%     33.000000   14.000000   20.000000    5.000000    74.000000
# 50%     47.000000   20.000000   26.000000    7.000000   143.000000
# 75%     66.250000   32.000000   32.500000   12.000000   282.000000
# max    138.000000   88.000000   73.000000   30.000000   861.000000
#
#              SM_SG
# count  1021.000000
# mean    207.577865
# std     164.596402
# min       1.000000
# 25%      84.000000
# 50%     159.000000
# 75%     297.000000
# max    1272.000000

# %% [markdown]
# Remomear colunas com titulo extenso e converter strings em tipos numericos

# %%
df_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1024 entries, 0 to 1023
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Data      1024 non-null   object
#  1    pm25     948 non-null    float64
#  2    pm10     998 non-null    float64
#  3    o3       995 non-null    float64
#  4    no2      975 non-null    float64
#  5    so2      1024 non-null   object
#  6    co       1024 non-null   object
#  7   IT_SG     1021 non-null   float64
#  8   SM_SG     1021 non-null   float64
#  9   Total_SG  1024 non-null   object
# dtypes: float64(6), object(4)
# memory usage: 88.0+ KB

# %%
df_base = df_base.rename(columns={'ITAIM PAULISTA': 'IT_SG', 'SAO MIGUEL': 'SM_SG', 'Total':'Total_SG'})
df_base[' pm25'] = pd.to_numeric(df_base[' pm25'], errors='coerce')
df_base[' pm10'] = pd.to_numeric(df_base[' pm10'], errors='coerce')
df_base[' o3'] = pd.to_numeric(df_base[' o3'], errors='coerce')
df_base[' no2'] = pd.to_numeric(df_base[' no2'], errors='coerce')
df_base['IT_SG'] = pd.to_numeric(df_base['IT_SG'], errors='coerce')
df_base['SM_SG'] = pd.to_numeric(df_base['SM_SG'], errors='coerce')

# %%
df_base.describe()
# Out:
#              pm25        pm10          o3         no2        IT_SG  \
# count  948.000000  998.000000  995.000000  975.000000  1021.000000
# mean    51.345992   24.273547   26.905528    8.534359   191.833497
# std     24.464972   13.665451   10.008805    4.799747   158.961679
# min      9.000000    3.000000    4.000000    1.000000     1.000000
# 25%     33.000000   14.000000   20.000000    5.000000    74.000000
# 50%     47.000000   20.000000   26.000000    7.000000   143.000000
# 75%     66.250000   32.000000   32.500000   12.000000   282.000000
# max    138.000000   88.000000   73.000000   30.000000   861.000000
#
#              SM_SG
# count  1021.000000
# mean    207.577865
# std     164.596402
# min       1.000000
# 25%      84.000000
# 50%     159.000000
# 75%     297.000000
# max    1272.000000

# %%
df_base.tail()

# %%
relatorio = sv.analyze(df_base, pairwise_analysis='off')
relatorio.show_html('Relatorio.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report Relatorio.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df_base[' pm25'].fillna(value=df_base[' pm25'].mean(), inplace=True)
df_base[' pm10'].fillna(value=df_base[' pm10'].mean(), inplace=True)
df_base[' o3'].fillna(value=df_base[' o3'].mean(), inplace=True)
df_base[' no2'].fillna(value=df_base[' no2'].mean(), inplace=True)
df_base['IT_SG'].fillna(value=df_base['IT_SG'].mean(), inplace=True)
df_base['SM_SG'].fillna(value=df_base['SM_SG'].mean(), inplace=True)
df_base['Total_SG'].fillna(value=df_base['Total_SG'].mean(), inplace=True)
df_base_hmap = df_base.loc[:, [' pm25', ' pm10', ' o3', ' no2', 'IT_SG','SM_SG', 'Total_SG']]
df_base_hmap
# Out:
#            pm25       pm10    o3        no2  IT_SG  SM_SG  Total_SG
# 0     44.000000  19.000000  41.0   8.000000    5.0   21.0        26
# 1     56.000000  24.273547  29.0   6.000000   22.0   25.0        47
# 2     29.000000  24.273547  29.0   6.000000   72.0  104.0       176
# 3     42.000000  24.273547  27.0  10.000000   56.0  101.0       157
# 4     48.000000  24.273547  27.0  11.000000   81.0  106.0       187
# ...         ...        ...   ...        ...    ...    ...       ...
# 1019  51.345992  30.000000  32.0   9.000000  100.0  111.0       211
# 1020  51.345992   9.000000  21.0   8.534359    6.0    2.0         8
# 1021  51.345992  24.273547  12.0   6.000000  331.0  389.0       720
# 1022  51.345992  24.273547  26.0  11.000000  263.0  333.0       596
# 1023  51.345992  24.273547  19.0   8.000000   79.0   86.0       165
#
# [1024 rows x 7 columns]

# %%
corr_matriz1 = df_base.corr()
corr_matriz2 = df_base_hmap.corr()

# %%
sns.heatmap(corr_matriz1, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlação entre as variáveis')
plt.xlabel('Variáveis')
plt.ylabel('Variáveis')
plt.show()

# %%
sns.heatmap(corr_matriz2, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlação entre as variáveis')
plt.xlabel('Variáveis')
plt.ylabel('Variáveis')
plt.show()

# %% [markdown]
# # Nova seção
